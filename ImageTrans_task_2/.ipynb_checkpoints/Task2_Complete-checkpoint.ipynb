# %%
# %matplotlib inline

import cv2 
import numpy as np 
from matplotlib import pyplot as plt 
from matplotlib import image as image
import easygui

# %%
# 1. Open any image

# %%
I = cv2.imread("image.jpg")

# %%
plt.imshow(I)
plt.show()

# %%
# 2.Crop out the fourth quadrant of the image

# %%
h1,w1,d1 = I.shape
S = cv2.resize(I,dsize=(2*w1,2*h1))

plt.imshow(S)
plt.show()

C = S[800:1600,800:1600]
plt.imshow(C)
plt.show()

# %%
# 3. Rotate this cropped section by

# %%
h2,w2,d2 = C.shape
center = (w2 // 2, h2 // 2)
d=45
s=1.0
M = cv2.getRotationMatrix2D(center, angle=d,scale=s)
R = cv2.warpAffine(C,M = M, dsize=(w,h))

plt.imshow(R)
plt.show()
