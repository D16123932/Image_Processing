# %%
# %matplotlib inline

import cv2 
import numpy as np 
from matplotlib import pyplot as plt 
from matplotlib import image as image
import easygui

# %%
# 1.Open any image

# %%
I = cv2.imread("image.jpg")

# %%
# 2.Build a kernel for sharpening an image

# %%
k1 = np.ones((5,5),np.uint8)
k2 = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]],dtype=float)

# %%
# 3.Apply this filter to the image

# %%
F = cv2.filter2D(I,ddepth=-1, kernel=k2)
plt.imshow(F)
plt.show()

# %%
cv2.imshow("Image",F)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
imgCanny = cv2.Canny(I,150,200)
plt.imshow(imgCanny)
plt.show()

cv2.imshow("Canny",imgCanny)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
imgDialation = cv2.dilate(imgCanny, k, iterations=1)
plt.imshow(imgDialation)
plt.show()

cv2.imshow("Dialation",imgDialation)
cv2.waitKey(0)
cv2.destroyAllWindows()
